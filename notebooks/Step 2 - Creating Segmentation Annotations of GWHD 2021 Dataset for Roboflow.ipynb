# %% [markdown]
# # Step 2 - Creating Segmentation Annotations of GWHD 2021 Dataset for Roboflow
#
# Goal
# * To convert the bounding boxes of the GWHD 2021 dataset to segmentations for a new segmentation dataset.
# * To upload the new segmentation datset to Roboflow.
#
# Resources
#
# * https://github.com/facebookresearch/sam2#model-description
# * https://roboflow.com/formats/yolov8-pytorch-txt
# * https://blog.roboflow.com/how-to-use-segment-anything-model-sam/
# * https://docs.ultralytics.com/datasets/segment/#ultralytics-yolo-format
# * https://blog.roboflow.com/convert-bboxes-masks-polygons/#how-to-convert-a-mask-to-a-polygon
# * https://supervision.roboflow.com/detection/utils/
# * https://stackoverflow.com/questions/1773805/how-can-i-parse-a-yaml-file-in-python
# * https://supervision.roboflow.com/detection/utils/#supervision.detection.utils.mask_to_polygons
# * https://colab.research.google.com/github/facebookresearch/sam2/blob/main/notebooks/image_predictor_example.ipynb#scrollTo=3c2e4f6b
# * https://docs.ultralytics.com/datasets/segment/#ultralytics-yolo-format

# %% [markdown]
# # Environment Set-up
#
# Part of the "Environment Set-up and and "Set-up" code were copied from this [notebook](https://colab.research.google.com/github/facebookresearch/sam2/blob/main/notebooks/image_predictor_example.ipynb#scrollTo=07fabfee)

# %%
using_colab = True

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/sam2.git'

    # !mkdir -p ../checkpoints/
    # !wget -P ../checkpoints/ https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_large.pt
# Out:
# PyTorch version: 2.6.0+cu124
# Torchvision version: 0.21.0+cu124
# CUDA is available: True
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting git+https://github.com/facebookresearch/sam2.git
#   Cloning https://github.com/facebookresearch/sam2.git to /tmp/pip-req-build-2h8u9d3l
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/sam2.git /tmp/pip-req-build-2h8u9d3l
#   Resolved https://github.com/facebookresearch/sam2.git to commit 2b90b9f5ceec907a1c18123530e92e794ad901a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from SAM-2==1.0) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.20.1 in /usr/local/lib/python3.11/dist-packages (from SAM-2==1.0) (0.21.0+cu124)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from SAM-2==1.0) (2.0.2)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from SAM-2==1.0) (4.67.1)
# Requirement already satisfied: hydra-core>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from SAM-2==1.0) (1.3.2)
# Requirement already satisfied: iopath>=0.1.10 in /usr/local/lib/python3.11/dist-packages (from SAM-2==1.0) (0.1.10)
# Requirement already satisfied: pillow>=9.4.0 in /usr/local/lib/python3.11/dist-packages (from SAM-2==1.0) (11.2.1)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.3.2->SAM-2==1.0) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.3.2->SAM-2==1.0) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.3.2->SAM-2==1.0) (24.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from iopath>=0.1.10->SAM-2==1.0) (4.14.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from iopath>=0.1.10->SAM-2==1.0) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->SAM-2==1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.5.1->SAM-2==1.0) (1.3.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf<2.4,>=2.2->hydra-core>=1.3.2->SAM-2==1.0) (6.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.5.1->SAM-2==1.0) (3.0.2)
# --2025-07-13 15:21:13--  https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_large.pt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.226.210.15, 13.226.210.25, 13.226.210.78, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.226.210.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 898083611 (856M) [application/vnd.snesdev-page-table]
# Saving to: ‘../checkpoints/sam2.1_hiera_large.pt.1’
#
# sam2.1_hiera_large. 100%[===================>] 856.48M   185MB/s    in 4.6s
#
# 2025-07-13 15:21:18 (185 MB/s) - ‘../checkpoints/sam2.1_hiera_large.pt.1’ saved [898083611/898083611]

# %% [markdown]
# # Set-up

# %%
import os
# if using Apple MPS, fall back to CPU for unsupported ops
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
import numpy as np
import torch
import matplotlib.pyplot as plt
from PIL import Image
import supervision as sv
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor
from roboflow import Roboflow
import yaml
import cv2
import shutil
import roboflow

# %%
# select the device for computation
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"using device: {device}")

if device.type == "cuda":
    # use bfloat16 for the entire notebook
    torch.autocast("cuda", dtype=torch.bfloat16).__enter__()
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    if torch.cuda.get_device_properties(0).major >= 8:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
elif device.type == "mps":
    print(
        "\nSupport for MPS devices is preliminary. SAM 2 is trained with CUDA and might "
        "give numerically different outputs and sometimes degraded performance on MPS. "
        "See e.g. https://github.com/pytorch/pytorch/issues/84936 for a discussion."
    )
# Out:
# using device: cuda

# %%
# !pip install roboflow
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.7.9)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Requirement already satisfied: pillow-heif<2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.58.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)

# %%
# Replace PLACEHOLDER_FOR_API_KEY with your Roboflow's dataset Private API key
# More directions can be found on the website below
# https://docs.roboflow.com/developer/authentication/find-your-roboflow-api-key
API_KEY = "YOUR_API_KEY"
rf = Roboflow(api_key=API_KEY)
project = rf.workspace("gwhd-2021").project("gwhd-2021-object-detection")

# If not specificed, work will be done inside the dataset.location directory
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in GWHD-2021-Object-Detection-1 to yolov8:: 100%|██████████| 588937/588937 [00:07<00:00, 77345.32it/s]
# Extracting Dataset Version Zip to GWHD-2021-Object-Detection-1 in yolov8:: 100%|██████████| 13034/13034 [00:02<00:00, 5556.77it/s]

# %%
! pip install supervision
# Out:
# Requirement already satisfied: supervision in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.3.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (3.10.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from supervision) (2.0.2)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.11.0.86)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.11/dist-packages (from supervision) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (6.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.15.3)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.67.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2025.7.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)

# %%
# !pip install PyYAML
# Out:
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (6.0.2)

# %% [markdown]
# # Preparing SAM2

# %%
sam2_checkpoint = "../checkpoints/sam2.1_hiera_large.pt"
model_cfg = "configs/sam2.1/sam2.1_hiera_l.yaml"

# Builds SAM2 model
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device=device)
# Creates SAM2 predictor
predictor = SAM2ImagePredictor(sam2_model)

# %%
# Create segmentation annotation labels folders

os.mkdir(os.path.join(dataset.location, 'train', 'segmentation_labels'))
os.mkdir(os.path.join(dataset.location, 'valid', 'segmentation_labels'))
os.mkdir(os.path.join(dataset.location, 'test', 'segmentation_labels'))

# %%
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)

def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)

def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

# %%
def bbox_to_mask(base_path, split):
  """

  """
  images_path = os.path.join(base_path, split, 'images') # path to directory of images of the current split
  labels_path = os.path.join(base_path, split, 'labels') # path to directory of annotations for the images of the current split
  segmentation_labels_path = os.path.join(base_path, split, 'segmentation_labels') # path to directory that will store new segmentation labels

  for label_file in os.listdir(labels_path):
    root, extension = os.path.splitext(label_file)
    image_path = os.path.join(images_path, root + '.jpg') # path to image
    label_path = os.path.join(labels_path, label_file) # path to the corresponding image annotation

    image = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB) # Numpy array representation of the image

    predictor.set_image(image) # Feed the SAM2 predictor the image


    with open(label_path, 'r') as f:
      lines = [line.rstrip() for line in f]

      if len(lines) != 0:
        for line in lines:
          bboxes = []
          coords = line.split(' ')
          bbox_center_x = float(coords[1])*640
          bbox_center_y = float(coords[2])*640
          bbox_width = float(coords[3])*640
          bbox_height = float(coords[4])*640

          xmin = bbox_center_x - bbox_width/2
          ymin = bbox_center_y - bbox_height/2

          xmax = bbox_center_x + bbox_width/2
          ymax = bbox_center_y + bbox_height/2

          bboxes.append([xmin, ymin, xmax, ymax])

          input_box = np.array(bboxes) # Represents the ground truth bounding box points
          masks, _, _ = predictor.predict(
              point_coords=None,
              point_labels=None,
              box=input_box[None, :],
              multimask_output=False,
          )


          polygons = [] # Stores the mask predictions as polygons
          for mask in masks:
            try:
              # sv.mask_to_polygons() returns a list of NumPy arrays where
              # each array represents a single polygon.
              # Within each polygon, it is described by the (x,y) coordinates of
              # the vertices of that polygon
              # (x,y) coordaintes are represented by NumPy arrays
              polygons.append(sv.mask_to_polygons(mask))
            except:
              print(f'Error with file {root}. Skipping')
              pass


          bbox_annotation = "0 "

          try:
            for polygon in polygons:
              if len(polygon[0]) > 0:
                # Assumes predictor only outputted a single mask
                # Therefore, polygons only has one polygon at index 0
                for point in polygon[0]:
                  bbox_annotation += str(float(point[0]) / 640.0) + " " + str(float(point[1]) / 640.0) + " "
              else:
                print(f"Error. Len of polygon[0] !> 0. Check file {root}")
                pass

            with open(os.path.join(segmentation_labels_path, root + '.txt'), "a") as f:
              f.write(bbox_annotation.rstrip() + "\n") # use rstrip() to remove trailing white spaces

          except:
            print(f'Error with file {root}. Skipping')
            pass

      else: # If the image doesn't have any annotations
        with open(os.path.join(segmentation_labels_path, root + '.txt'), "w") as f:
          pass
      predictor.reset_predictor() # Reset the SAM2 predictor before making predictions on the next image

# %%
print("Converting train images...")
bbox_to_mask(dataset.location, 'train')

print("Converting valid images...")
bbox_to_mask(dataset.location, 'valid')

print("Converting test images...")
bbox_to_mask(dataset.location, 'test')
# Out:
# Converting train images...
# Converting valid images...
# Converting test images...
# Error with file 497f9dd3e34f946e46ebfafca71ac763d5a1adf4ad8db288b11e2240a13d4908_png.rf.92e464a94529948a89fb27f1863aa648. Skipping

# %%
# To check number of files
# Expecting train = 3655, valid = 1476, test = 1380
directory_paths = {
    'train': '/content/GWHD-2021-Object-Detection-1/train/segmentation_labels',
    'valid': '/content/GWHD-2021-Object-Detection-1/valid/segmentation_labels',
    'test': '/content/GWHD-2021-Object-Detection-1/test/segmentation_labels'
}

for split, directory_path in directory_paths.items():
  txt_files = [f for f in os.listdir(directory_path) if f.endswith('.txt') and os.path.isfile(os.path.join(directory_path, f))]

  # Print the total number of files
  print(f"Number of files in '{directory_path}': {len(txt_files)}")
# Out:
# Number of files in '/content/GWHD-2021-Object-Detection-1/train/segmentation_labels': 3655
# Number of files in '/content/GWHD-2021-Object-Detection-1/valid/segmentation_labels': 1476
# Number of files in '/content/GWHD-2021-Object-Detection-1/test/segmentation_labels': 1380

# %% [markdown]
# # Update YAML file
#
# Align YAML file description with new segmentation dataset

# %%
with open(os.path.join(dataset.location, 'data.yaml'), 'r') as file:
  data = yaml.safe_load(file)

data['roboflow']['project'] = 'gwhd-2021-instance-segmentation'
data['roboflow'].pop('url')


# Save the updated YAML file
with open(os.path.join(dataset.location, 'data.yaml'), 'w') as file:
    yaml.dump(data, file)

# %% [markdown]
# # Adjust Folder Structure for Roboflow Upload
#
# Roboflow expects a certain folder structure when uploading a dataset. The following statements will make the necessary changes.

# %%
# Remove READMEs
os.remove(os.path.join(dataset.location, 'README.dataset.txt'))
os.remove(os.path.join(dataset.location, 'README.roboflow.txt'))

# %%
# Remove original label files
shutil.rmtree(os.path.join(dataset.location, 'train', 'labels'))
shutil.rmtree(os.path.join(dataset.location, 'valid', 'labels'))
shutil.rmtree(os.path.join(dataset.location, 'test', 'labels'))

# %%
# Rename folders to match Roboflow upload format

os.rename(os.path.join(dataset.location, 'train', 'segmentation_labels'), os.path.join(dataset.location, 'train', 'labels'))
os.rename(os.path.join(dataset.location, 'valid', 'segmentation_labels'), os.path.join(dataset.location, 'valid', 'labels'))
os.rename(os.path.join(dataset.location, 'test', 'segmentation_labels'), os.path.join(dataset.location, 'test', 'labels'))

# %%
os.rename(dataset.location, 'GWHD-2021-Instance-Segmentation')

# %% [markdown]
# # Upload Dataset

# %%
roboflow.login(force=True)
# Out:
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········

# %%
# Replace PLACEHOLDER_FOR_API_KEY with your Roboflow's dataset Private API key
# More directions can be found on the website below
# https://docs.roboflow.com/developer/authentication/find-your-roboflow-api-key
API_KEY = "YOUR_API_KEY"
rf = Roboflow(api_key=API_KEY)

# %%
# Connect to gwhd-2021 workspace on Roboflow
workspace = rf.workspace("gwhd-2021")
print(rf.workspace())
# Out:
# loading Roboflow workspace...
# loading Roboflow workspace...
# {
#   "name": "GWHD 2021",
#   "url": "gwhd-2021",
#   "projects": [
#     "gwhd-2021/gwhd-2021-instance-segmentation",
#     "gwhd-2021/gwhd-2021-object-detection",
#     "gwhd-2021/gwhd2021od-dgg1n",
#     "gwhd-2021/gwhd2021od-od3w5",
#     "gwhd-2021/gwhd2021od-youfr"
#   ]
# }

# %%
# Upload the new segmentation dataset
workspace.upload_dataset(
    '/content/GWHD-2021-Instance-Segmentation', # Make sure this is the location of the new segmentation dataset
    'GWHD-2021-Instance-Segmentation-V2',
    num_workers = 10,
    project_license = "MIT",
    project_type = "instance-segmentation",
    batch_name = "6511",
    num_retries=5
)
# Out:
# Streaming output truncated to the last 5000 lines.
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/073e3a608e65126ba07fcec190f03cbb3fcc1e47cdf3fb6c70c1f91e596b1bb4_png.rf.f22fde73a5a8ed2f8b435c9b019854ad.jpg (9lPrLwkZzscqMi7H8QZV) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/076a8ddf55e025ef4114ac9065f7c88a0f6686031227ac60ee4d944724061ca0_png.rf.9ef90c9c8e3f0c34e0477dbfbf0eb72b.jpg (G4TPtzDLugidgLe2ha7X) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/06f97c2c7ff80a4baf439b64195700d0d9829573e523be476a83f991f33f26a5_png.rf.a5a73b34e60a310d8a43f8c658fc317d.jpg (CTiVJZ4CM8EsfDqULmgC) [1.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/078eee55a02d1b4c1996100975cdafd1431afafb89ff370ad6f1b3aeee725783_png.rf.e98e1980dfb065c07bf69ea1765e1b35.jpg (jf9SCu1UrEKTeAWSD0B8) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/077ec8de285cfe4a3b98ff850f3a1abba34e5f7a0ad7185cde2e70881d81489b_png.rf.727fb1ca6c7837127d2bc7bdddd8b217.jpg (qNwbruF1QsamCxffb4wb) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0725bdae8b24453a0b076e1448a79cb09d596ee5df6ab1de7ba01c363085bb1e_png.rf.5c97ba350b14ece57f861b252b33012d.jpg (t4hWQjpdGJscYzdVjs8o) [1.3s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/07a04269fce1625b97668ce0f63a745f18f6729ec8f45e9486db2375202ccc3e_png.rf.4c9d27bfe292d1e1672196c92c152913.jpg (wP4FgsSzFMQ2LSQVqpYg) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/07a5f0973a65c2bae19decd360b6c7d0759635c3005e159fdb36ddcad93eb58e_png.rf.fb725c87b575ccf8be1df634e9e1ed2f.jpg (cDlRlc7ISzSz2UeNLndC) [0.9s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/07dbe0b96cd8148611628c3ebff31e86ce0b081c21d439f15ed025169cd82d46_png.rf.3690f6b0a71d034e1e517c25025189e1.jpg (1M55JTsIA0VYRXPbBf61) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/07ee4d17a4a4ed2ca503a2a95ada38efe76644b26211e7e511ce63ced5e62bdb_png.rf.cbe252f8d4978e103281add5811950c9.jpg (ysSVgbu0LJEk961l1BxN) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/081bbcf1c4ccaffbe2ea23a6883e676298bea5a50c89b7b9f18e0a9f20130ff9_png.rf.de548739f392e75c7064755489130baa.jpg (BFIJ6AqmjvaTqpB4wJPG) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/08186579c8b3724c1c8810a7e7d6362720bbaea664caa368ed1331543782be89_png.rf.3b431d084ddcc81ea68d9fde6bfe6cbe.jpg (qdwVRGYtiYVFeElSeHQX) [1.1s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/08e233c7dc49c9c9dd5c3ce94f39f665f0d64392715f08e88e86d2221387760b_png.rf.afbc7b863d030936c60df8621a622727.jpg (y7D7UViv9IcgMv9VDscy) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/08dfc8a8c0f6359687ad6bfac760e161f1afd74693c1152a80d86909137afd53_png.rf.53882c3b8885c4c85a16d6d9b3d5ab56.jpg (7GZ3gs0Ee4poaQ5zwKc6) [0.7s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/08623a42107a2068ba6200398573b9e0225c5990b17eb7d4d00c0f48547fb1fd_png.rf.77205d2e9ef1de5c90290cca7c8a3f63.jpg (rYPVDBGxxh8TwyNNID6L) [1.0s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/08b76e4e557f532262c90eaab44717b8089669fe9513d7881c5b75e29fb47d81_png.rf.9b8a7ed394c781db90e21740e714bea9.jpg (DsWncXTZjtQby8DgpSWE) [1.0s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/08fab4fdaa0a0c37d3805b70e061ce7a336266d67a9487970f798bf701468dbf_png.rf.81c4797756b3c5b5289bab1c40cdafdc.jpg (ZPLL8WGXYe0PyxOjKNIB) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/095b10930f2ec3fb9d8072ebe83cc7f8917e301838433a84c6caf8c457d4a798_png.rf.19ca3abf8b586ecfb2628fb6aba282c7.jpg (WjS8JSgXOUUbDYGX7VBR) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/096a5b91ea6c128177891880afe4ccd1a2df2dc3f30007df244387d6138c95c6_png.rf.7501b4994edfb3515d597f0763d244c4.jpg (BZsWZFxrf8wjTHGrIsR5) [0.9s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/097fb472a7311fe84f93c3ec0277ada1f100fc4ca94705bc65b80116e280486d_png.rf.f1faa7aa4dabd74847ba38d6b796a77a.jpg (y2vOeU4WQpWiuOgAE1C8) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/09c940f99f7c8fad56af5106fea52aec7053a554506eebe382919217684f63df_png.rf.8f10f522e07dccce60ac2bd1809832be.jpg (ji8wGGM5ROrhtVKcv0VD) [0.4s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/09994121c798bfacfd80f58f8943dca07fc391bc31d43647e68ee0aa85897f28_png.rf.8f0303b04f22cae018aa4a81e7732dae.jpg (pdy3Zd4JurawCgcW6b2b) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/09bd3064174a7aae9b949cdf3b464609640e844144e58ac6ec2615932058fb88_png.rf.1ccac0476f1c82329f77971d2029ecc1.jpg (LnVObuDC4M6Xtk1X2Jmm) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/09c18de990f0c801cc24eeeec765c425d42dffe48c7498ec977501af9c68308f_png.rf.4ff0261f776aebf0ba2403f040669b45.jpg (EehH6JFxxt6QXlGd3k3L) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0a486a6586e9b89a314682e15d028d34f898f402efa6595e3fa7e0525cc0e838_png.rf.d69fbeab6dec1cd40d8733c6c25a7a72.jpg (JI36z1bvRaCzpQkhBxAF) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0a3937653483c36dfb4d957b6f82ae96dbdc7ba36cc3d8bdb633bada3023c085_png.rf.4c2bbb059eed047ed8025fec56ab3ff2.jpg (P8gVm0HNyJjeL7Hh4OOF) [0.7s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0a4fae2fef5eaab6b331aa1f3cf06896ab8206e7c2cb24280e6710c4e2ed3c40_png.rf.caedade469533c36b7f3db9d3993a72f.jpg (olM6gdb8sWfXurcGcqmx) [0.6s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0a671b00f0e2e3cf164e424da4cdc03a296085f102ae62922e074cc45b61a1b8_png.rf.4154789affcef28bf01c250a61a96299.jpg (yNUEIDqmWyk2hWPdEY60) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0a512c8bc9a4c5c71065357f50a3fc18ad31170132d03ff4409d5fcf8fb1f829_png.rf.b2808e974ab27b0f95b2f2e4634ad258.jpg (9trfYa8y5Vijw8hTSSwj) [0.5s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0a2727a93f2e43557e73915e3747e919d1a3791691c11a477cd17c43cbd7620b_png.rf.cf6e4eebdeab87b36dedaad608d718b4.jpg (zkbWboz33SkRxbV8bPjP) [1.0s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0a938aa9dd7a40e058200c22cbcd5a3225c30dd5dcee34949efc9d382cf7d7bf_png.rf.2383d165c24737e504b3c370ab463bd4.jpg (C12O5191jEIiA6qT0ZOF) [0.6s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0aba23afc14ba473f452f2db8bfd0f1fe3346bfb9a2a8b3b2b319a157c6ac979_png.rf.d5883b2706fb527a4bface1d6c524af3.jpg (7JWrnYLzY2ahJa9t91qQ) [0.4s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0aa59db196947b1c52ba95719f6f129e33a9857fecf8879306890569f6389d13_png.rf.2b867fb588e54fd6d7832b928d53e3cb.jpg (J5wxWLXDTSA9VuP4vsHI) [0.7s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ab73a485a03ef6a620ea9dc77d7fccfe8307bf684aa7f1c5e295a48a2471950_png.rf.21366b8cadb329247fac012180aa90b0.jpg (SBZdnpiNhhgCPDEPE62J) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ae2b60233ca6c1d76f76df2dcdda304ba6c46cdf9c944c386cda5796590a817_png.rf.841f62b52c686abf22e255a9854fcd3f.jpg (EFEvTeWMba1CexWUUbr2) [0.7s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ae9b1f31324a493bea1fef7dd5afe675234584d2495dbe4d43c829e6dbcbd86_png.rf.bfe48cecca8647b9c476b49c0d2f6603.jpg (NkREAXXRvwObTCYfloxh) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0b10dd94d6c99ee16cbaf41ea20029c1a3036c742e1e9b0d628763a5e5b9c312_png.rf.fda5cced26b702bef10629638954f78b.jpg (danSAGIgoRKi2FXIzBqx) [0.5s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0b1aa5d36f01c5b4ba7f147cd43b19e1512f0e5cb624a634c659192e34341796_png.rf.7650eb85ffe5c78c7970da93729c101f.jpg (QwGqQnSxvjgveNyLAMhS) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0b31b10b9f368e0387892d4d4ded12d019667c676fae67d1dec4aeb3d80cb3ef_png.rf.ceecacccc9ede8c76778df744b8406a9.jpg (MQIeCn2m0MLzg2RhgC1J) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0b6f0d41f22f336a3e4e684d846d30fcaf6533e7c6a101ae7a796565b6322ea2_png.rf.40f41840dd550e5a3503c4f1330ffb20.jpg (3uIpoyaxrJUs2Swb2HXi) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0b67003385598be001572f633276f17b8de925e76cb17aff4323d12b79cac03d_png.rf.227e63ac167c977cb6a01aeca47b176c.jpg (tS7ERx2xIa98VLnm7v8a) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0b775826146d2ef47bae4774d6368eaa050da573386a8ff735e9c4fcf141e25c_png.rf.7e9f1ab3b2f82a6dd36f87e9d8e13d70.jpg (0SdzcDZircmWwqH08xlq) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0b3a3c6b693106b2b2ac77d4123cbd0a1057273f007c952ccf19c6f75fbd2d40_png.rf.fe0c6567329621f0090c34e2cab25678.jpg (xlUM4DmcnIJqiK8fokPa) [1.1s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0b9b10b6f13192d207db77ce7850e0dc86ce2322eb93fdc6728cdc96a62d8e69_png.rf.f790f86a1101511637b1bf3ec2dc23e5.jpg (AgfjfvFlUbapqQyGAEcb) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0b5d94b36da13ceeb73ee6171ac0d4e73d53ac5aa3a4e576e08a965fbbb25aab_png.rf.3e58e0c4938dfe81def4027017abc20d.jpg (rlznCQhYThag3Uy7jOJ8) [1.2s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ba47d6e0f67a852afd871f12174d47083f10e60a73851ad1aa71bd78889f08f_png.rf.ad259b14abd1d1028f5379113ff16d50.jpg (9YmWho4N7zML7c2d1vjX) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0bb11dec052f8e2804a01c214fe24ca1b4123ce32b8fc8220a09dbbaab192629_png.rf.878ed670b18c2c463b70bc7ca6939552.jpg (3MzFeGHGcP3nS9PmCbCg) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0bc099b42e222cbb65ca6382c40dd0bb07b9db91152de3e72fe97e497dade670_png.rf.d5a662dcd0177909fd6f38ed5549b364.jpg (mtS1YJMQMDCY3I0Sm5Lz) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0be53b5fed5dd9daabf28eb0ec8dfe5e78791bb4b60aa46b8416e08557892488_png.rf.5060592a11f77804a877a56ffdbc27a5.jpg (AclJv0iKEn9isnbU49LB) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0c0e291caa73be0fabe25316adf98801c143167a4acd610c9f3559596ac7ccbb_png.rf.c2ba1a32be7e06aa1e9ba3ecefcb0438.jpg (Zmew6lWWppRKLXZsHdF3) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0c81e845096bcfc4f2d8be4492ffbc0806cefef24fe64d28f24a6db74f26c026_png.rf.d725830f1342082ec6781c2ad5e92b1b.jpg (STjgNsWw3UnCvFM6EJai) [0.4s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0c0ff70d5b3e45bad3413e8fb765837dcb4e7736cdccc5a4af3cf5834618cbb8_png.rf.28740a97224a88a6c03536c2a446da90.jpg (MrfZU17HEh8MiXx47csK) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0c1d0e61ee5bb1334ccdb8e852de51e56ac3e3a217d2e894bccc1fcf87988676_png.rf.25c1a674567f07f5bebdd26c61b693a8.jpg (3pq834He792RA4z0e7Dn) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0c2ffeac5d082dbb05575aa7d749ed6a3ec9e4ced97dbfa2ae8af876fcd9b685_png.rf.df95eab83ce42cf7e92a72318d4f8e8c.jpg (DyaLRdTRgH1GDDNwFoTe) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0c7c65f4ca2ae02375c08703c6517a0b88058bc09dbe2b54e59eaaf735886c6d_png.rf.6a189e975a30f1b6ae35a88ea161118e.jpg (US0boNP4evpJNr3TIz7Z) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0cb450fdcc1de972756e2572038baad62cd02fa0c65bc3543bfe9efbe75343b1_png.rf.8ec6fb15267f2e38583516e51a13f6d9.jpg (J9xF8OvxiDraWJ1XJJn1) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0cbdb1da73befee8a5d2fe99122b05b7ce76cb2fd3d933d6f22806096b04bb21_png.rf.c5af0e3cc8e22c6212935a1dd5595036.jpg (MKBPxzFegwZa0N2NjGgH) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0d3073caebfe132133c8680d7f20d02f4e93cd2cf98b975a31d3f0a8b56b9b1a_png.rf.db8374e2d0c865e7641f4179eaa5f436.jpg (6VwYmtyrJX9djTnG8SNs) [0.4s] / annotations = ERR: Unrecognized annotation format.
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0cc01a509f2c255403fc75d28b346333a8b2d6f47956ff3575467af4d0ca2fc6_png.rf.3ff39360d901710294bb0d11974b50d1.jpg (u7USKesjdJCrnBR9GxzL) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0cdd371bd063625854dafbd26af4b5b72e6473d28aec12738e11844e161ffbc3_png.rf.f4eb13469af9690651e1a2a4d4ab691d.jpg (1taiiRrA4afj6V8gTVjS) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0cd8eb1cdff10d5e3c214932476f77103772189b6229ffbf113c38b0fd341f77_png.rf.911b544382eb98bd99411be4c02932b7.jpg (HKMCK87AP2WV5jsJ6I1w) [1.1s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0cda4a1cfaba20c110f8fa58d129c137639c27d66a22169dbe90315baac29500_png.rf.3a700b4b495d4fa204c67f88847cf941.jpg (4O8AcvLdWk2tXxIXhpP0) [1.0s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0d45fc52e71b1de84f3bc92138f718614b445b3ca82f071a6a33c0f977e436d4_png.rf.e49b8db508ccd888fb86b9a66d5155d2.jpg (BKbTmOhEL9ioxc5R6LKX) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0d3c7d4b2f6411f2a73a66951f161de26021518fad17d04ac1e04f4c9d447674_png.rf.ff6933cd909063d8e4e0b1aa76e30235.jpg (PCXrl5VLmv5qkMQjq4dv) [0.7s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0d097e8583ed760fd620b9035524452752ddb8a76ff28b915cc55397ce76d508_png.rf.886d12b7c4e38cbfd7cb34eab98c6133.jpg (lSrgsLNTIs09misCuqpR) [1.1s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0d5785bf6c481e4c19cd0f6cfd6d09e3191411a20bd1d5f0f4132f41a4f7746f_png.rf.ee6e64ed3bfdaeb9b1e41473d1320489.jpg (HUfi1ddDgovMhc3W3a8o) [0.8s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0d8d639bf3f94d2ada9cc29f53d4461b10b86ca619d3901bd9d217bea3fbbbcb_png.rf.54ded42d0df371b97d2823c5e0c0e47f.jpg (tv2ZWe2qkgvt0jLtTyGw) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0dc80aaed2e966cae61f19c7e10132c4a44a755f9fc4c9564a6712ea81cd44b2_png.rf.4fb6e1274275a832f7e0b44a4a41234b.jpg (6KYhwssfabLmedaQy2Jx) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0da4d1d33bf2dff8d3dc2df1f756a91647e2f58fd58db5cfc659bfab6adac70b_png.rf.ee91cf9a2f00e98aa70419375223db3c.jpg (2BezTjNbwAsfABZWghnu) [0.7s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0dd3f71f431ad71ec5a256ae0791cff31ef6819cb4978234c3b21b00af7796ea_png.rf.159a187932bed5eb61cd39423c93512b.jpg (wh4qzxcYavDdLHTckf80) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0deda1c5163812e27dad5f8265d4eb0890a0721200c0ccb165dba40cb4f27947_png.rf.dd722bdeb518d2c71cc1afc10f66eeab.jpg (PZde1c1CikA7aQoniZYd) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0e230d14dd56318067a1d153f33df3ed7dfa8f0a7f27600f4d2488ebfecf6c85_png.rf.89b62fe7d3d18446dea97e9872c62ac1.jpg (BXaBPIAdniGw3OLc7dfb) [0.5s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0dd3352b5c7942a6517d1f0c0dbfc552f7a88cb4f7b7828d6ab7a80bc67d9125_png.rf.8ae35df29f849d6e1aab2ce6a9d7e173.jpg (ezB11SiQbfUIhBpwjd89) [1.2s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0e0c6e234993cdcb746a3513b5ed8ba2c03a651cef6125504d3e107da3423a52_png.rf.c9fd0eef13fb58dd78d49b9394e23498.jpg (gDNZPle8Ak36XXSNAOQM) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0e2c84a632ced8b647c6c800ddb1a436c4050f91c5f278f2242eb1811637d929_png.rf.65013887a6c052b349c093ca47aae948.jpg (UATexSfQ4vXZyJkiXcjF) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0e2a889cdae8978f6846fdbfd94d3b0e11b30a79ca4a1437b4d4160a940b9f6a_png.rf.47c4744810d633f3deb0db71dc07ec22.jpg (PlQ1i9Q4QdXANRjKOiik) [0.9s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0df1be1cc9246313d339f8a45eaf6ff4d361472b21e35b0a48af60d63a6d0f59_png.rf.34ae0c70fe75ba409eee30b85345ec6c.jpg (YK6dg3gLvZP7zmXq4G1C) [1.3s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0e487dee8c5d2909a8def87bfd7a08aca05e8919118ce700212734a1bc93f2a5_png.rf.7d011af6daeaa52174e20ff7552a4352.jpg (m8iTc9uwAxpTurVU3Jjx) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0dcb5d1b5a7a4f7728643867998336a8b3fe0ddb325a59754de652a1d2fa8f08_png.rf.e753a28c4dc321e7764afe2ce7fb4bea.jpg (g8LNdgaZq68tHuTTAx2c) [1.9s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0e65787765189ae9e4b7c1f3787739ed6b18c3d01a31a1089491208aa84a220f_png.rf.957c2347222226902029b8dc639f4f0d.jpg (oIAIqaAqqP0WjtwWa5tA) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0e712d4c194408e2ed67568364ee5c41a74b8c51c9f90a6467ff721791a2e827_png.rf.89e43741e55005e498936a761fdcfbdb.jpg (77Ht7r7jOsnpOqRk3WC7) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0e678e52580ffb3a341aa195a739ca50a74988737c052fd6a56b6b6903cb849d_png.rf.90fda749017f6bb2de4e1597000b8d82.jpg (7dWficOYimQxiDLrswn8) [0.9s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0e78e6c1c4f0ba120b967ad5ba4953b1b19af61c9026611b7c3c1fcf34cb36e3_png.rf.e7d00b962143da9a4c1233a48c87bed1.jpg (WZ2m845UDtd8Le5KwEt9) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ea3ad4ed898a705a5366e51b7e5db6f7d8e6f49e34f203e034d576f60be4af0_png.rf.92cd39d2b11abe59a1e651d15560532d.jpg (UvJhz95rCmvooO8krEAP) [0.6s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ee3b9b357ccc1b8a15b07765f2707a79a82bcc0f21b918d44f942af0b9060d4_png.rf.8f53ec21c3e4a54cfe8ca420114f08c7.jpg (oNoasRUkGCLQqyvj5K2L) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ee3cf72b9fada1793cf575101f66a73b8e859be46390eeedbc823e872e1acd7_png.rf.0b960fdb340900de33c0c3ea9590e885.jpg (flSx7ntFkqcCyoWdLvom) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ec72aed3f0b2468d848b523a64c743d5b53e264e0d41a2ff9865fcbaae6eaba_png.rf.850a78550bfddf79922ad0853039dd0b.jpg (bL2uR5hm3NXxTjLr8yMn) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ece838a54b0fb628a9f8bdd990c22148111fb1648f0afdfb1bf5cff32508d48_png.rf.c876158354aa0bd833ee1aa8cda5ef56.jpg (VtwkVV1k2iFWbedBAwNr) [0.9s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0f0c7e32a9ee88e0f8751d630a40ee996273d6668ee3dc13a6a608ba1ddd481d_png.rf.8be9d478a48c020e1a82368fd47c6430.jpg (d7JIzz9LpXEOeEvb0mR4) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ef333bd24f8020b805fa7623207de23ddae642749c15ac4bb535c1f47206403_png.rf.9cc746753820115240570e4b940082b2.jpg (IekpTvXYaoaronlRavtr) [0.7s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0f3a73a7b03536d527227eacdfbb5d560ee49022cf66e77c63252e503f7921e4_png.rf.b8d99c2f698fe7ae31b455acd0e4bca7.jpg (ZINcNSClyptXdsihahVB) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0f3071c22c268d284246fb689819fb09b1de261dcbbeb2bf231f8334a209070f_png.rf.961986287f2465b445dd0a1f9ffdd908.jpg (8vKjTihOBpeTxR7Go8gP) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0f4aab9c793b79eec29ef4194d280babb0cb97f5f7cde36fa94e452dd651efad_png.rf.defecda8071357cbe0b024f7aaf89de7.jpg (cKAcQqWhLHWaVD1Ddpbf) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0f50aa426cf30c06d524d3fae6e31ac12764b3a5a641219510ba2352435c2bb1_png.rf.aba9d01644dc2e57c007db0b7cf27b54.jpg (zmPBgWzxM2gqcSqBNkKq) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0f9fe77ab342b6e4f0816cf95ac746f619a515c35f924aca63ccdf40642ac331_png.rf.184e562af9e538bb7af9b907c4811d06.jpg (OTpRiUpfIKMcBX8laykp) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0f72b45231106b43290c8092910a0a35b80a495a2e56cecc25053af21d3a503e_png.rf.ad2c67aa478cbd853b2545eb30ff78d4.jpg (DQLbk0aKs9rqxsuSoSig) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0f6824024d3892a012daa314ddef4230477b09ea1d6548ace53058ca21a13bc2_png.rf.04be7e41e8b31f0633ac08e3bddea416.jpg (lO83UcerYHfJQLjVcHL3) [0.6s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0fa9803798434d7cd13824fabb60f3eae353625db4893d71ba1b8e576d1bdc29_png.rf.a9d924c836ff14bbd94c024d0da3fca9.jpg (m0qYxuzg79dMpHuFVwuy) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0fe00ca7927b9f0a4be9ecc1ac4b1e93e5f9b5e10c96e1f2c3e2371bbfef3c06_png.rf.723ea535f317c7ba2b8778e8f96ae738.jpg (Z5rh1SuAgzlQhMFSKgJL) [0.5s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ffacddc9ea0fdf02b5c13a9b467661428559a98ae985eb20b73add2259a4894_png.rf.8352f49d9f1eeea67324c30de3a27ee8.jpg (tDjl5f3kO6AEGYMokK5N) [0.8s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ff58cfeb77aa39702b50d8db727fe2e5e17d4a1e7e54a23fc7bc82a290896c4_png.rf.50d38bb4ac2a9fa62584543876fe268f.jpg (MmfwqhD1m5KtXNSlTwM4) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/10422b741f5bc0be2f775c1bba09e4faa33933341ea78ceb03700326da3628f7_png.rf.76208e960d559a8c354484c779ff28f2.jpg (k6xqQcy5VtaMaAC8EUdH) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/0ffc582c16501fab44fb0f736c3ac6476606c4692909d0c9a8b590387f6e31ef_png.rf.2c3ec03e4ff4845057e6c54c05073fbb.jpg (gvXCqeTR6P47Btt0Aqv1) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1062154c4c2e710cacea5147fd2f96b3e428e378260f08822ee9adee207866d0_png.rf.b673121c3eb82330bdadc8821a7d567a.jpg (aIKN0VfdAjlVE2UNDDqj) [0.8s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/106d79f076e04d8d4186b89d0ae3a160b7e023f6cebba5a41ac0e4b5ad9ad92a_png.rf.6d84210333ba77155526ece5a35908d0.jpg (ihJ15kuywIB8gOQpGvB0) [0.9s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/107d7b85224c6a0dd84dafcc00401400019b94ab89cc6aa07a01f2cb1a5356f9_png.rf.11e716956fd4aca76a14af3d7f24eb45.jpg (piuFDKr2xs2AxeCPcV2O) [0.7s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/10868f26252033fb490e44a54bf448195b7e6424a630f86d48cc76d99c9c4ba3_png.rf.1fa7d5ea87aa9cc8280cf2265761118a.jpg (b9f3mG883mXISQBlMA0q) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/107f9a2815bc99f301d194d6b8e3d5e716c0b846146f7751348e940fa51db1af_png.rf.45c2dfa25ae86aafe583cecd473accd0.jpg (fJdtNx5UxwZmASE9JPfW) [0.8s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/107c34f6b75d17e9147aace676fd7321cf8fa867c82909c27309b5d817a9093f_png.rf.f3951324d4eb53d951d771f3f0341a7c.jpg (BJfZtxuJqO6HVoG1FyhK) [1.1s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/108a6f400aa4d18441a73f09397fceb0171bf86e465ebaf40126132ad6568888_png.rf.895efbe3cfb4bb1939b317218a5362aa.jpg (QSc1orrI2zf81v0M8zIK) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1094cfc83aa3de6b16a86a4f51c2a02fd38da905da6dc546b9e990dd74eefa29_png.rf.00d7cef350e18f663911252b4b9e7b11.jpg (RwdHnnAsKK5lryG44adW) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/10ce5f2d547a4186f7086bf5e5e5d3591df3cb40cbe2c209e6f0e85e907a14ff_png.rf.e5e304b00d0ef2f156735f8ec5a1c7c2.jpg (rC71GEXZdC3r6nDwU4oA) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/10e78519c78e5461d15d902ff7a4b31cd18ff9e8c7d4d4a542d1a2ce64050108_png.rf.4e0f8530e23e0b1d07af32e4abb4ccb4.jpg (zK0Q1iaKI79VM5bIibW4) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1115f8148e039cf06b77e0fef1b9acbf4d0341baa819330770611c17d9e5a541_png.rf.0cce66b342a183753f6d351efa82e027.jpg (awxtDtrTB68GCYb7EbTI) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/112f090d0faf01eb782145ebb9adfeac641c6f0ec8e6bcdc20287a7eb1d97283_png.rf.9026abc0d30dd51a93eb107b6f564849.jpg (ke5FOhUasyE9Z51MYjir) [0.6s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/113c39d37229788236d5c4b8a39452c005ccc1d8140f7d3bc5824a34230a69d8_png.rf.81c647394f70291a5b07cd7af0cc22ce.jpg (QPJntLmcy2yRXOQ0F1GX) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/113c8e6233abda351b31580e4face75deaa8ff7624799e774d40df847b35b9c5_png.rf.cc34ff7790b2bc553b9b69c1d8116a37.jpg (W48MGIaLvV4FFdtOmUKH) [0.5s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/113aecd0a952b86a69800d371c301711dc4cedaf95f5a5559a687fce985c26c7_png.rf.d3f713deda78d7ffa70df01c8527ae57.jpg (hz70PrMLiONZcQf7lJtD) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/11799ec7f1c2c2594937e4aef4e266dc0fbef3a2ddc5c5c717df5103a177d43e_png.rf.62174ecdf295ba5a69cfa8385f4d1c56.jpg (j9xOdQ8tEnXotZVBy06j) [0.5s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/114d83952aee29440718ed54795548dc0e3ff8045da8278d761d531f3cbf5d3d_png.rf.9562cb1a981c26b840af9d1bb66e328d.jpg (cDC8UVbP61gwaq0w5nje) [0.7s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1139b8794f26cef443acd516c887f064065d7eaaf695bcd6258e5736c4d2c635_png.rf.91429008385ef3051e81ea3e4f217c39.jpg (PROjjyYMxbcNqSx51A8s) [1.3s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/115e025add19999a23718fcf13c7c39614b08c8fd37a3f9c84a3b08b3765b0dc_png.rf.5084a1cd2f6a90c6f7b88682ca562fce.jpg (6KjWX7uFEVsaus0lsPuJ) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/117d3e3a6ace6f93d28c68fcdc6b2618a745966b6139da1de73d2fad64e91300_png.rf.420d62b758678d64abbe8527bab8802f.jpg (mXXJC6ciRHAv7BYXbe10) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/117b1a2be7af537135a858c5b52d2b45c613da6ae7d153ec64d4faf2f9997ba7_png.rf.66c09b77c2480a55b66283cb91edce87.jpg (xlJoc8kENvszeUN19kCp) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/11b2bfd862feb1a58d3eac0a03c21afb8d5db1cd236d4b56e9ee4d05ba1d56e8_png.rf.fc2e57d5cb7c25a4807823404ba42424.jpg (q1n0APtNLfucizStTWwq) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/118d2e4d04d7f0b5cf005f93ae38b5b8286b953bb04cd23d33253fe70750aa0a_png.rf.f829d17988c993aa90acc4e6606a330e.jpg (VcZKs44r0d0SdX6fzBZ4) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/11bc25b2ab4a439bcd960db19ee223913f97769c1c272ca8d5c6beef10d8f7fe_png.rf.45156faf267dc074c2f289183739c4bf.jpg (CsqRRnT2DrTVfI1Z6Z5B) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/11d491b05865c46944bfc488e9a8529c46f420c6bd89221cd2a92910a293ac7d_png.rf.184672ed93b3941acb8b6b1958461eaa.jpg (56VxI0ZJ5M54U1aNzGIo) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/11e92ebd7005f8210cac382f00f8119420e14804b101d3771bda508a17d4f86e_png.rf.8d5d03d1fce3172eff99f31242c39d50.jpg (zGLZzboKedvDUmEYH5kx) [0.6s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/11cb60a28348dc2900958c20fe678c5f76c84dadc84f3b7ffbc73a2e644552d3_png.rf.d2a9d4e8c316f89ecad609fb88fa370c.jpg (53PPSnUyAsVGvZYhX7qL) [1.0s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/11f123fb46dba437db0096de1626d85b54dca38157f5b3de228cc895d461a45d_png.rf.2cb9c6a360934a84a1276ed84ee71c2d.jpg (pYCFECRe3rjpMDgrHfHZ) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1232718ebeb5bb3f96339b5556cf45d34d5f9bcbc80215e39e4f5ed3900b0d68_png.rf.a34d45f8f49fbc14dc7848861fa98827.jpg (DSr66qPPV22ra5GZG3cn) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12421504268e0c36e905ea12119c44d3c3f19cbc2270abc14247feb1800b85fa_png.rf.c96aca24df06a112aba95867a8be2949.jpg (z2yfd7VPFhWTfaz1mhHc) [0.8s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12318349dc3e32feeff67600f96b1ad04e1ebc4dd5c9b878d09ae75cd4bf5f5a_png.rf.52d421a4a4cf3ce409bda8ec68ed7f67.jpg (sj8WhKoJGAG2saUXaGFQ) [1.1s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1272f69b8f21fb47e410178f948946645626f82045e1eb3c58e73dacbf7023b8_png.rf.cb2fb19fb43be96c16b37cac6c217f88.jpg (1Hx0mOUVlVQRYIpt0y1A) [0.6s] / annotations = OK [1.0s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1246dd4cd9f38b1505e77fee9c95d54573fcf499fd2a6c40acb5eee0d047c9ce_png.rf.8f2586ed652024419ae8af21aaf837df.jpg (xOSasbJDf3q1w7VQANhq) [0.9s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1251d16d3fc2cb59aa772a3ab0084d696d309eb7dca21a0e9739503888f1877f_png.rf.43ecd994a2aafd742767dd5ec95f3531.jpg (15yklp4qMjhqay5Do0am) [1.0s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/129c5f7743ae899b3d0c5058b3599ea657625a9fe986dac1ccb7435f63e2d28b_png.rf.11a0249a1738ba879896a8b8e6e91c98.jpg (rsZkJXueLTIeQlCKeYnc) [0.8s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12a0a007bf3c7fbe3881c0beba80ec0ebb79d52e1014229f618ec110128eec38_png.rf.ca874bd7193998d3ae4bb334abe41753.jpg (X0tFXZ2ZtmywDFsJiPI3) [0.8s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/127a25ddab062d86f69e6656941047d82b6b720891b5fc8eb2a1d9847a015004_png.rf.de1b95b38111347673510a0d11a08a2a.jpg (Ax2IKP9PNQyjL7hGOlxu) [1.2s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12aa25142713e36a5b13a0c627701558710b324ec16225d64bc1343adceb958c_png.rf.96ff0960aab9204ac19a759e99035e39.jpg (Dvbjb7FmYySqVxaRu9QQ) [1.1s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12bc7dda0b9aaf197e3a35d3cf6115d54037e33f24221b05debcc283b941cd34_png.rf.76cf46d71da55a0ea09bb3298414196c.jpg (boQf4bAGjqjCk1vzmRXj) [1.3s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12bf5d4d4cb6cd4cef577a443591936342ad2ed7c3d1108e0109c56fdb05e5ac_png.rf.a380787fea4105e1aee7d8b705cd5b90.jpg (Fxjuf9oIeSvcHASor6ii) [1.0s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12bdf3d58bbd7b465d38740d6bd18c918232fdba157463906eca4b67c42c8d26_png.rf.958243d5974781008cf73ce194686571.jpg (XSUSUuHFD7Who1hkMtbS) [1.1s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12db62ea87323f608bfc2dd22b096c20989c4900729d677f20b72e6254bb9680_png.rf.11cb01e1c1795dac02c6e854d72f97e8.jpg (DMWR3s7ta5h6UDkOhwDe) [0.7s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1304c5e3d9e356747aa9e1ebd8104e19055484783f54dd277bd83baba38c0f48_png.rf.03963aeb94fde648e1b54f5b79f2c1c8.jpg (pwqlVz6Uow1WJNxRpMJD) [0.8s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12c16f6c6a3060f641b11fac7f2ae3bef3a98a2bb285d0b49836280b10344113_png.rf.17e4f77e1da0b1aa06dd83ff3119af31.jpg (xX8PQ7ce4e5hKcvInTAr) [1.0s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1334a3ce9aefc8aa2f2b08f6fe8857f76300a7304aa0e10e5401a5c7dea38779_png.rf.7b5a3272621a491f2a86934557a7b21f.jpg (vOk6iBt1CoDsu6Qw6Rq6) [0.9s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1381ecb5ca90ac9531377fa46e29411ef1fca6e494fffae12c3dd351e2cad1fe_png.rf.eab9014902517bef8f87678ab6578582.jpg (iEL8RWNp0fXtxlpZvcHp) [0.9s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/12d25ea64c413fc6900f281d44021f23ddc4042d59560414e21ef8131946d49e_png.rf.bb2463891f91ea28b567dc6422d9fc61.jpg (TqGRSYMR4aZ5VtSumBTC) [1.4s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1388ec233af62b8e07f3101f1859ada4d072c186649bb54da995c8417e9fec72_png.rf.31516bb34fa843aa1ac98f97b35dffff.jpg (kdyiw6oo8lVTXZHNgeJb) [1.1s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/13bb872b9a8e042e869e6aece7b9fb4a6cd2a1b794e9b116ccf683e19ac4a94e_png.rf.7cc0ef33d5897b32574a13f2d50eaf72.jpg (xlihIO74JuI8D0lyOLoo) [1.1s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/138cc0bc88aa9f2fed6f5181e6636ab75a5fc3241f4296d75b38062ea70993d9_png.rf.e1c8537a8093e788409f9ddb5c1fcd14.jpg (vJkKs1gHRzW20MtDvf9K) [1.5s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/13f0d5c0303b8360c8a519dbe38c1afea8804906b591d0f7090c03bd53af923c_png.rf.58845cb9af1bf37369e6d303878a0789.jpg (716KpCtnbbvYY5HhtP94) [1.0s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/13bafa54084319c74d27cc8d149d1bbb032deed68eca3d1f5f0a1608458a3bd3_png.rf.114b1086e85a25bb263cda9c6690ab82.jpg (giixAdhEzcgX6EOX8m6V) [1.4s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/140fc52766594c4410d9da66ebc38597620bb41d501020595f912b01f5f10bac_png.rf.4bf33884a8650a615a685814d73c9498.jpg (Je0F6uOGgSvbxIRziwqI) [0.7s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/13f18bc85e9e1d21d852fe4705e01118ad2a9b6dc9683505fc2ac47530a0983d_png.rf.4d35c56e5efdd1ab505590de1c4a57cf.jpg (QRrEe9ZszJMxM1cxpb36) [1.1s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1418a3b49254026e73e19b6ec1fed0db748d41f65beaabb731d99fcd18623d4c_png.rf.8617525f86194d756247d48c676482e9.jpg (X0DGNzusB2bLyBzYv7Q0) [0.9s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1452e76eb2d4d7d69a9334f3d0c1b7f54e047621c089b3a6c7756ff83a10902d_png.rf.cf6ba76f89329a042983ad4af45ea8f9.jpg (W2HX8Uf9sKPkUjXdnVQs) [1.1s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/13f96853d132fd4c251a45ced050d5ed62b1bb46e78a73638b1adedb53df735e_png.rf.3cf4618ca77c9414fd3a3179a67358ec.jpg (HtADwFqBfh9Tk98Gzmnc) [1.6s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/140f11f6796e686df440d1a688afa220ace984b4472d3879f8013064a2b9826b_png.rf.7506f78c56a525efd2d7b138d523599b.jpg (PYVivbagxMzk98tXVvOJ) [1.7s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1493fbde4e01f128f4131d6faf8d6dd81cdd8480619650648c40eeb4d6faa5d9_png.rf.d545574fc9fe61c99e98cb3c64c22eef.jpg (4IvyXYpLi8lNtwXgMGSz) [0.9s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/14800f9ebd4404313e9012c089bf2616f858f080d5ccabb92a79350734bd8294_png.rf.1547ebb19bc961657cfdca913ecd423a.jpg (E4xcxphPjiebtBuBlLjj) [1.1s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/149ce8584ac2d77ffebe5916208b309da0aea3bd810160f1ff4288385118e116_png.rf.22ee36d9f4b73e50a08fa069964e5137.jpg (59rbbOiFiLGA1xVVOPtB) [1.0s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1499631c930fbd75434025a9dbba8825a1d0819f217c57a06fd006cea30bddcb_png.rf.acc507c11e9c3c80376c8c8d02a9d39a.jpg (LPHzZtGoSXefyoDLq475) [1.4s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/14b5b29e8259db6fbe6d1afa49c65b06bb751f96ba1e0c59eee753867604ac17_png.rf.7b285648f023ca68990983c6c04bc173.jpg (v7UfuMYpAje7QZE92fi7) [0.9s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/149961a9cfcb3412de565c447663b3048e8926cc4860ec0b5eab0de257747009_png.rf.3a3be7924196f6621ec77c2d56bf8824.jpg (2Hnz3gw55GBuwN7QQOcS) [1.7s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/14c9aeb29056e609b27c8fa3e4d82d0826a52245f4d00d44dea49997d2380da4_png.rf.29a5b145c77c421ba1fa58ff01003187.jpg (4oLKjQz1sGpCHkThjOHu) [1.0s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/14e598cdbc8cc336db61c060aae7c542087229439ca942e5e8fd83283e038bd1_png.rf.cdc52d7cb2a15243d4c7185b5f1430d0.jpg (oOPoLFXR1azGFcrxoQDQ) [1.0s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/14ffc4bb5393acc4442ca6c150a644f8379fe20cd6f6f30ab7aa465d9a9a24bc_png.rf.82df398a5bcf3178fe23e51f3c9a6cc6.jpg (TsAxBtCPVIQAwJFolPdo) [0.6s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/14fccfa0bc5f681838b5cb135e1c09bb45ff8807afa42f4d86db018ad8781858_png.rf.1fb9372934cae9e8419af4e3b2c21e53.jpg (0Il0JP4KmjgDGOtJF2zq) [1.1s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15032fd8c6071995d4d52474889c663968bdf6676811c5104e9216c47baa4205_png.rf.aad35702764e8b297a0a9950146d438b.jpg (D0m654F1PFuRSFl7sLKV) [1.0s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1502ef700923a453aca2dd037b8dcac5331af055497c2f6391d2de73c5da433d_png.rf.cb9484df74049cece51454fa66a6599d.jpg (h5MNg0c6bJ7IZ79MHkHc) [1.2s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1510291ee377942e71e4e67416736d891914aaf370b1c04439b050f461470b5f_png.rf.abb830944aac85c74b2e2b78dee67f7a.jpg (FOClQsYDL0eeC4Jo2cmP) [0.9s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1553ea9721726551ec70e33b22023a0386488d61d9083286bab42e74e87a01ec_png.rf.2750b01263e952dc379b09d1f875aa20.jpg (Ayua3gnh6ivfVaAmHpPj) [0.9s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15596df6823fd717a8d128bb0712a2db6d2806383195c0cbf84d7cc2dc65549c_png.rf.5e663f5091d772b3922891a85d2b48a4.jpg (DJipZJVOWKQ35ltN2kE9) [0.8s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15631e7ac46b4b4bc668fcb65d1a4574aeecf4a9f7e26245b86ce553488b2b92_png.rf.b56c5d25887a16482cf6e65c0eeb0585.jpg (743zMERvet8bzLv2FiEv) [0.9s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/155b3c1181cdd76f8f1e4d3ead2d6144a71d1cf6e1c72414aaa493352e0f10d0_png.rf.2214fa051fe095c8f73ba213e447e975.jpg (r9WYgywtu0ylkV8r2hOO) [1.1s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/156627d7ae9d6662c75a5f87c254222d81d87f3981cefaaaddee28a2e0e6af06_png.rf.e22f923e1135275a0c203bab285163e6.jpg (mEuGInRmaRSc7l9RxQGS) [0.8s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15635205532789cc41aeb4011de1d000be07dffc7187d521e7f82fe620c8fda8_png.rf.b67fb9196b62b57afc57442c3615b977.jpg (uAFWXEbcy64AW3I0CN2o) [1.2s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15800e727b07ef731ffcc0a0c6d0d89d7248b306cef1c5663340c87dd768b093_png.rf.68104ed363c632d8ca51f75218ce3dca.jpg (wuOrhpvJhsqHHk69xnnj) [1.3s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15ae4bd37648e67629e28e975856491e56370b03bd3bd8e85ee0b7bb7a59339e_png.rf.f9c3536c940264b51c06d2b8762179e0.jpg (bMGwUOMg5SPK228rvVDa) [0.9s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/159ae241978e6cde4ee909e21168a8b22c8d6127ad142b0fa7cca954add73643_png.rf.ecc2ea9c392af49423a9829e70ba22fc.jpg (qJqaARhhUGIlUOcxYPMX) [1.3s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15aca7f957063f1f4989605540c82ccfb2942bf67c85e8e5dc1a0c31d10d3d35_png.rf.548d2c70460e8ed21b6a8d87d99bc3be.jpg (oOgdELSgCxDfw6hitKvD) [1.3s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15c000e382083e7394038d2922cefeed2116c7c55e2f160089b05ecf4e289da3_png.rf.7bbfab3136186687b57d0b2c89dfa887.jpg (9gYkByls59abL1edSN8z) [0.9s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15d34652800a53e703e553baa2cbaa388900d73311d84f5bfffb3fe9dd933182_png.rf.dbdca61e1b4a8dce2bff0488a0cb356c.jpg (sn4xR7kKfrPbJh9Kv9e0) [1.0s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1580b9bb24d478ace31948bdc77deaa121bf2c1798861959f2fa51d2d9c4a821_png.rf.837ce99dbf114140aaa19233b3e62fdf.jpg (jyqkMD8a05iUVBjPU3sL) [1.6s] / annotations = OK [1.0s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15d95f2c757a11749db32d045518c29d04d0196888b04ea9924d55eb0bd5181f_png.rf.0f515a0433c511da390164597e79f8c0.jpg (wC3PNaTRP4fnd2IHw3Zb) [0.9s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15f91e56f367ccd43ac90c90a0047c98e4277f03b08845409f457a215ab9379b_png.rf.b960e9bd3cb92e8c4167d9d1096d805d.jpg (UBs3OVYAKq7hW0KasMAO) [1.1s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/15ff3bc853fb9850808e238e253bf4bc7daf12064ea4989e5d3b13dfd0409fa8_png.rf.c8b5f3c1fa457117cc2df36d7feb776a.jpg (ioXo4fAZPwf31zb9g3OD) [0.9s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/160cd9a8755835fbfce80b491920ade99d4f80137c43feabe89b7269f4811d48_png.rf.8f44f596d7069048b8d96eec378bb0c5.jpg (OsZdrQWr6UKAQZzrHCxm) [0.9s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1610f2f4d6beae69a23e4dbba81618e3b8aee43e2641f95d8b95e57af0b6227a_png.rf.7f9dc3794a2e90d5e6a91bbc56f27be0.jpg (2ifyTRJmAj6htL0Aog0x) [1.0s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1668bcfee661430ff3e5c626de7623903a91943004b86144ca67dbe21ccc1951_png.rf.146e17768e56fcea27d00fba5144a935.jpg (5jUAaQW1otXdnSvYroJW) [0.7s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1632ee8f3410114197b8a0857f9a9b5d44afcfe7315c45912bb69c0d5e43d0ec_png.rf.f08c460a4f82b95fa4a0900bdd1802c4.jpg (KuxfUGEzW0M0sZN0SktE) [0.8s] / annotations = OK [0.9s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/166493a3434a768b262175c5d28df8a58e736d6be5f8308088ee26a7af8d35f0_png.rf.186638b7aef7c4b36d62e82b6a363c53.jpg (g4LSdeqxQoIYE2VfnYTt) [1.1s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/16700edd4087d0445b4d329f6a853a2e7403b42e10836dfec65cc42eb2c27f46_png.rf.67b1741d8f486ce0a6403776f39ea057.jpg (OZ4pXQaiTdC1E1jAPCkv) [0.9s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/166d31b4a2915654eb53fb388e13f2107b177cd78b678f3afdc1392dd2906b79_png.rf.ba7f57929ab56c9b6ae5e1aecbbf04f2.jpg (9BUrEsSRRtGWnHcr25ZE) [1.2s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/16787455b6e872a7ade1083689cf41bdca9cc95eb0b9fe43e67d58ccd1a3491c_png.rf.d46d067491f77705053e8e0d204dc559.jpg (Sw3Lsai9eDF9GnJdAVhg) [1.0s] / annotations = OK [0.8s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/1683d39a4d9b1b094d719f4d75d0e18e7cfb007e1ac219bfc2c0eed7512f1ed6_png.rf.c70746865e9d8189a5c9c75011b918ed.jpg (huZ13F2WwNJkoseCFgJ9) [0.9s] / annotations = OK [0.7s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/169349a2c8f97a516f7ad3727de9db91dbaa224b74e14f3a43d680a5bc5ae524_png.rf.6851263c622fca6e80a3c7d9278f46e0.jpg (S3tADfg93MWWYAUhvWsQ) [1.0s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/169b9c9ca7fc4238fe6749d0a5f7cd22d3b4c00b61e0f02c97113ccc2249f56b_png.rf.b6042d060b0288262b6dd60b44ff26c2.jpg (quFdixip1xkNNyFx4NF2) [1.0s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/16a6c3da368806c2fe26b5c945a5e7acdbfda33f50ed0912c175cab591390f93_png.rf.224afd61baf5caaf09a0e8dec1f72369.jpg (GSzRepHeqqRXq5mZ4EdI) [1.1s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/16b9a006a9eacc12c26ee7e32c08ea6b91af601d2f38266f1977f5ca361a4e39_png.rf.f1661df0df6d73940ce9df5f5f17f831.jpg (utuSaIPw8bQig5LSdFbp) [1.1s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/16d17c1373e66da6da6483f71477cbf82e277618969a66433ee5c4a4e5ed0a20_png.rf.b57d05d613ae217657de9101166d4765.jpg (pnMGd1lpG3ShPL6m14AK) [1.1s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/16dca6c15f0d06e923449f989047490e930838efd6e822dbd1e25fc9ffc6775c_png.rf.e4b69dc3f0d5af296006937c8d3d238a.jpg (LSImFLfMgYSKPt8Tl3eM) [0.9s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/17528cba85011bb2c82d5e223407c0a2c599bc18f35b6d96459c80bca8e91200_png.rf.b9e7c4f4e06e9fe850c4d1ffcf745e07.jpg (jI6NozTP9yV2Joo38J8R) [0.8s] / annotations = ERR: Unrecognized annotation format.
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/16d41ca4dd4c3bbc933fd42bd986d60435c03aef250a854659eb10fb0b5dff2d_png.rf.4574250c693cc51da2ab7469ef1674e2.jpg (CII2y88meOi4137Kz0ES) [1.0s] / annotations = OK [0.6s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/train/images/16fb20db6545ea5bd767441f60385fcde178515f95218e5d05b500d29d7ecccd_png.rf.391e449add04ad9aff64d1476fbf9316.jpg (eqSDPeC3fZxC7uTtWcOs) [1.0s] / annotations = OK [0.6s]
# ...
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f538aeebcdbeb66ec90349fceddf2fdd7514c3c0332cef4335b4bf54690917b9_png.rf.3dc0c1c7107e5a5ca461f7e43a58be9d.jpg (nwnWimWZXKqXy2DRkG3s) [0.8s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f4c3075faec3196b73076d77dc84c79d03c8425c06d245f7a75be617f471b7db_png.rf.1c1acafb6cc70201ab5464dd9809eb7c.jpg (RX9vaycxac2LOS6l2vxO) [1.3s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f52d9fd10ade14c348da8e4d726f109f6013965fb222913c01abde0901ead156_png.rf.5328577e4053fe98ba1f56f170ab7342.jpg (ZDcuqqxyfStCQuBl0zy3) [1.0s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f59bc58c165af43b4aacaf25afc3a00d7a4d87c3db38c46b5554e8b4f47e0ae2_png.rf.b43bc4abf21dcb9b2c15f45529eaceea.jpg (bUlhkIJhffP0kxAjakVF) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f5533ed03079075cba9878acba8c395616f9f2df45ee2cbdeb38b489bb37a269_png.rf.cfab70213520f1013fce2381e5a49b98.jpg (0DOI60WQprZQnGY83H7o) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f659548d04ae40188ff7d2b3390db1c0023dd7ab865360ab903e169c66cc6e77_png.rf.553046a54ff082ab96d8acebec9e81c7.jpg (bImfzlDYRL1tCcuGmn4V) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f73adc941d69296e150ece761cd3b3bd4c9dce80793e64ecd75bd8bc1e030cb0_png.rf.1ed42f077e1cd650d9142d3fe92188cc.jpg (mb5qy4KyYat1XQ9Iq6aS) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f6ec28d663f9d3209076c2df425a9eda3cce610db822df48dc240709691b299c_png.rf.21337cc811611e224ab7ce01919e488a.jpg (NY2Bvrwx1hJKvoS7J0ii) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f7a7597b6748da8d2c8a224bab9174b60fdf0ae4cfd0156145cee617905c4432_png.rf.689101e2a655218246e6a92f1e3bd801.jpg (a7jpz2jyLxKSXV8N22Ev) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f6b6b90cebd58a3acf44a0f1d5067a305f01c0200fca6c1a64bf68b06182684b_png.rf.c82a57f4970294512aac76f3f859cb14.jpg (h88IZiCowP43jzB1Zb1P) [1.0s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f7d233d426ebf643f9ffef1004d90c27da0b8a118ecedc69fb63144e288b5356_png.rf.817dacdc58d64d3505971432e69bbc46.jpg (fJgrrnQ132Bmge5YM0nX) [0.5s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f7b31a38c2edfb70a0eaaefcc005a97fd2b249043a2fc20750c14f9f73375822_png.rf.e9ab3fe570b43f4a05709433135dc561.jpg (iB6EfqStjMu5zKi47Otg) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f7de89d19e35282df5bd6fcb916541215c0a9115ecd476c4fc68996a8506810a_png.rf.5f288d65588d707e69889e53e05be321.jpg (DKM9Qh9Ur9Fiwo8MYYvj) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f7e153ba6b23523fd9c787289483466f691c8b6a154db2701e88ddaf58619505_png.rf.c8a21cadc1dc7b04c50aa40241f4486d.jpg (kfr1T3VAv9iNrCZPWnEg) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f82578e729ae3924051b693e0687279207f0130fad6edc2effaf15a30f2426b3_png.rf.27b46bb20c1d09987738984410f20c3e.jpg (2G1rFCMO84iJADQLXKIl) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f808bb7a05c7f8e68dc3237409f2326386749296542778bb571049fd949cbdd8_png.rf.1f79b95578e598636cbe6bda6a6b8bb0.jpg (7HleqnmhSnsddmjx2Wls) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f870f9c952ae9b52d0a5f24556ebbd773279087372dfe133a63d135c85b8bb59_png.rf.929c7ff285c727623f9c3fcf06804251.jpg (xatVBiVJGi4nKfwKCiZ5) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f89a921c5b7033f7cdca181bd96b7f0636b8ffc27aed43d70e2426f877146b28_png.rf.383db7543af5f1e74739a57182893980.jpg (6VNvDdeUdUWgKLYSI7Dj) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f8ae939586d040c1b11b72e3912e70ced8953dbbbf958952b626863668bc12a5_png.rf.3f5aff62e818ab7102e8ee5011bfa79a.jpg (JZpdjCarsNryx1N44eGQ) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f92e8584682a5bc62edb074204253e7d932cc6bf45870d38acaf2753cd8d558f_png.rf.8b04ede69a40de604b7a5664e9adba2c.jpg (1Z7FRRb9RFsLvENXJrsF) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f96eae055243c05ee46d44ca6039ad19add1d212b78a7ffb99a3b76f32f3b5b4_png.rf.3491cd2af8f3cf57811dc5bf67af8776.jpg (vn7g9E1967xuBseTwyzx) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fa242289cd2ceb0ed23b46a6815d95285dbc94bc523430f50bc45f615b9df43f_png.rf.0b559a778fdb44a524e23056e8ff12e0.jpg (qsxc9DsZemgi1UVLCrg9) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fa58a1c688d81eb4dca0a9cc07d4272a6a24b98564b5b51ac94c3c352f26ed1d_png.rf.7d026307d6b6687033890b7a7a4710de.jpg (kQOW5fC74gLrRR5FDu7m) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f98e4b230bd6cdb4c331c1653951a92d99b247397eb72ae744646a694212f319_png.rf.9a99919ed9499c83f90bc9b3c9dc8f10.jpg (wqIqXOJXvDmYIOuybrL2) [1.3s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f9bde62517aa2e0db14c866fdd57276701bb0ebff045b9ae377b56b12cf4d863_png.rf.7cfe64c27b3f2e5921890b17a2792ad2.jpg (pMnOjZf1LwiTbmL4QHaM) [1.1s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fa507918e2b9369254551254045fdcf0e9fbb24c4161cd325c1e7d7be600e8fd_png.rf.118f7d6d40eee09a9717cee86655fecb.jpg (FvKxm3MVKT3mjl0EOjAT) [0.9s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fae2e601b46a377990415ddd7d37936fa9ef38ee810e0e44427353e7f1e1d2e6_png.rf.53ac9c97cad7510fe5ab96ce708a9f4d.jpg (NQrSx23FpyFVwkqLHZsV) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fb159458bfa6dde547ff01e93faaae52c1a8a67245204f61b89f921bed7b6a3c_png.rf.2ea32c0fb8eb78a9f8fd64404fcf77f4.jpg (7DxrCyi0nbT5wD1HnSTM) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fa7ed8d52ad8ed6ee954fd600cf3c7d9c00c3d1472cc9d06829f1a18ec6bf5a6_png.rf.812f2b311913243805c0613b92f883c9.jpg (sSnoJHoxDNFiVDlKAQvn) [1.0s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fb1bcf1f642a58932390d67db5276bc1b7bde3073b46c5910ad91f402e305b60_png.rf.83db952b8559eae20c8f98d1b4239bc2.jpg (NC1B2e5KvhkXyohfFAAY) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/f9b3bb413bb35db748d4472f14ffa621ef1a5ff4eb4e815f157b83527b3967a1_png.rf.7ef862cac79494e01a370a8baba69478.jpg (7abht1qjuB4a7wJXdGUR) [1.4s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fb826010859108f4405e8edf41e2d8d2348d57f221f35a6e280281fd2bc2d071_png.rf.f54756d7a5db5fd4677a09aa13e9dcd6.jpg (BT5ZSItqp5280RARzvzK) [0.7s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fb5ebef62f70ab69d8888a746a2039873ba77e17d471c790496599c72366be5d_png.rf.2b98a67f638c71495a3102078145f2b8.jpg (WPjoaKUandnd1BJhbfne) [0.9s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fb9b0be25f25cf71664ff603a18718539a2cca489fb44f3fd582b983e5f6a71a_png.rf.c5e723ff45f390bdd81a6c4fbbc2920e.jpg (Chktw1HM4vsmNEA0FhcJ) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fba6ffb9f6639c0f72c2158b6beb7ea5d77eab0f96d347bba89c32b723e2f7d4_png.rf.fabe4f57bea52d194fabb424342e31d7.jpg (EoFy4IsUYNkpTTyokmbr) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fbdec08aaf1410ca714ce6a930876f791b88359370220cde6e6604a9c53e6fcf_png.rf.80895828e2fa3caacbb938b25e5c26f0.jpg (cz95t8xiBBYv6dXvyXtM) [0.5s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fbbc2c0d46e5e6cf0646f1e5a5cb88430331db3668f221a3b7660be3c2aa6208_png.rf.05cd68ef095bb1d936f1102560da820e.jpg (pFEBKQv9t4aNcMLdJoNu) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fbe253670c9ba5ad55906e38e155c0fc175d27cd32986dd3ce295c390a959aca_png.rf.ae20e74e0b893c61e5fc04b6cf283ac2.jpg (GxdpdW23qE8dAvTzcJPE) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fbed36fcea79afa3cf921d43e517e80bcdb9324b782560bceed1919255633444_png.rf.d44e13d1477e563eb9bc5f10ec174f60.jpg (WnrK63aCbi2tmrDIcstL) [0.8s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fc081619b2da016ed04094b51dd7db9848c14f17e0250177f970de2bc1872676_png.rf.8d151ae56b71e153bf424cef2b0afd6a.jpg (vDoWNsApzLHqZnGmvPbX) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fc2dca029c74ba57e38ea3e928c929d0fe2fa13e84039c6635d4878370c9c93d_png.rf.12138da79cc0f0760ee3f496236d0fba.jpg (GVb6Vn09a5mrCdMZfTql) [0.9s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fc45cfd13528e71cec9d036a48a05ac6261d9a877a76122c7e67ab694a950dbb_png.rf.134776667d464edf951d6319691e3bd2.jpg (n0E6Lm5DscJTuXX95922) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fc43ec53ced3be915d5e6ab0d51ced9d55684cf264d7ca2569b4b1af2eaec0f0_png.rf.545502000651c8892f308793c34cdd17.jpg (i0IWNvvyCSTaQ5D6jfdF) [0.9s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fcbd63af430e3329aaacb1b3ffa3d473b1f0b4a314d6253af81799d9662692b6_png.rf.ff2efaf0122451a8ab471b67740b7889.jpg (GTKHEmOChaIUkq5OOWRm) [0.8s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fccb03a58b2e11747d87a098ea2e7c1dc5927c2dbe9fa731255ef10c84cf5237_png.rf.ce8cb27aba57609093e7cbc0366d3ca9.jpg (5rFWphHxqkUz7gDrcok9) [0.6s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fcd1d5efff039378f422641e6f3580ffc01891a816843f0cd30f31e210cf9e38_png.rf.1904e1a54ca437860e44a8203f909366.jpg (NxTIXgbZpWHiG979bZc5) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fcb7b26fd1b5930466841eb7123ca3d1c3f22767b71fdf669ac7c16a90540366_png.rf.49d3f1d0fc3215ff3144ebc657692fd9.jpg (i7u4QkmoUEhbxcNwaTBK) [1.1s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fce2d7a3c0a13dcb70f74ab4ff9375ed2448e8e6c7e69d3d49a76ee75db847e7_png.rf.f695ec5dfc266f44800ab9fa17f36c46.jpg (YGpE7eN3z1OeA0UCipsr) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fd3ed717674dd5b4738e50ff3979e2aadf92df9853fdbb10d70aa4e8e58f2fec_png.rf.3d603a5a1a6a2435e5901f0dc2ddc16a.jpg (gMQQgCYfNFpYoM9yvCxZ) [0.5s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fcedd96a20a70ad7ce6455227559a0fdb00b78615daf493a3ad967df3e8a934b_png.rf.12e24f36551d0509b56b407689e2fabb.jpg (OYt4496E2ehJPVrA7Xtq) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fd004216b804b562e648edccfea411da1d023176755d8edde12d0f0d0f7ba207_png.rf.47dabdb48f77b1724701a9c8813f93e0.jpg (DT4b3Y4LDXQjRrRy1dLc) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fd403a748f425d7e86f38970c15b1c16991ed16f4e68ab413f482506af65847a_png.rf.de04ddee88fd295889b873ec3f881a12.jpg (nHgZpIA091nGplKJSLyE) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fcc3dfcb75d931429a6a03dcd15f8adf8ac6a7102cc4986a1e4294cf6fb53368_png.rf.21f639662d102cf68974f24a14bd88f6.jpg (yBBjp44rnjEM8rF8rXnf) [1.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fd76610700f5fdd7dcaddea0aac536ae9a52e3d87867c53dcaf19e3faf93af81_png.rf.2c4e218e31dd09ee5585766daa58d08c.jpg (m7naT8a7IwCTBeXkhKSG) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fdf6249303477478ec028e2ff47b258c588336ed2233cea852b62841be8ae227_png.rf.40efe75408baae532c5b723a8a5ced59.jpg (UhwtCKEp3kM7oHSVhwk1) [0.6s] / annotations = OK [0.3s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fe0526bfac47116532e0e98371e132f0ed43bc30ac3f0c1c89aca5ef545acc67_png.rf.bbe9d32e4cf36dc0ddecfbc0565d7bf3.jpg (0lMdSlYKqBuFCocXwipC) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fd85f4fde1212a86050940229ae6f5cf36b5bd4df453c8fa256532050352df87_png.rf.b3cf19e0dc839cbd354e49d8da2e247c.jpg (cy8eoqBdaYoPiSZl8yKY) [1.3s] / annotations = ERR: Unrecognized annotation format.
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fe0ca719790ac95adda79c9ef052889432dbc2f20be0ae787491d19eb9f0e267_png.rf.53107ce1f5c39a28508ebd0e418b24bc.jpg (1ipQ3JWKKoVymybrpvsO) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fe998c5e12e4f03c1b06ddfb60b29439aa80ace4ccda298deaa2819d0d5fe809_png.rf.1e267e7b9dd80ec15c83a00b06bfbb5e.jpg (yX7TMiGakbUsTx0t19Z8) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fdcb01ed27c0bff0eb942d6b726e6131f3643a1528a169ce7ceeaeab079545da_png.rf.5cb1c2e597da8e70ff31823a37dc7589.jpg (DETZVMNy3HDg0vZPxj3N) [1.4s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fed80366baae64791860c10984a97b6d44252ebce897664aafd8fbb6ca83f1e8_png.rf.dd34d0d948f4ac074041f6c01a2c7b0e.jpg (B95cmM4vjFcVwDq8qk6F) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fe3b5d54a0331ac74431d171673bf33ee045875d71fbccf4f8723a15a956e6b9_png.rf.2383d179a788826d93e0805a3e70cefa.jpg (cfm5SZJh2cbURyRLpArR) [1.2s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fea7644fcb2d266a95c4ee3c084aa06558d28af0e855c70bb0d3b095210cae09_png.rf.922192b6fb160c27f5e4c20f643bbb46.jpg (Jl2DtsQqcb3JPQ0cmP9y) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fee2d476930b108a41ac978dc214f19c5330d98db68fab4f7205a570e9ae68c3_png.rf.5c8a06944ff7f6266fdf1170b5d35fdd.jpg (1Fo4CCAeVaJmKBs8hEos) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/fe9358d0653f3d52c4795e35554ba10c6de17756533ffe52a34b3d099648000d_png.rf.830d72e0628c9fab3df0ee8be3c387fb.jpg (8YcpbG21RWQL7TWup8lT) [1.3s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/ff0d1f54cf2986633afe8613ba4df54525fcad4322040b9a63ef9ae45596d77e_png.rf.1fbd9fc2be22b3cfcaec9925e63189e5.jpg (jn3dGUYZxBTgbqfQIJVr) [0.7s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/ff0fafb5486a8f6e14a2be4717f4cf6fd61750315e0df2da1d3407acc33c3c03_png.rf.118b2f3cfab21a63ede92739fe19163c.jpg (8SxjgEr6zsD69ZUqq0P0) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/ff4ed1c667c2dc63561107432705e6b305a4baf431ed94c8c4481976015eb1cf_png.rf.7f37225fe7339488e59b1a20e92c7f1a.jpg (EHZJoXQ3WwvVn9LoErkN) [0.6s] / annotations = OK [0.4s]
# [UPLOADED] /content/GWHD-2021-Instance-Segmentation/valid/images/ffb3b22d6d45597bffdbc710c6fbc3107a783a614d096f6a219411569d57d3f2_png.rf.3cfa5f48da017fd5f8d5553d862a66b4.jpg (qffalbmkGWJCXhVuRmE4) [0.6s] / annotations = OK [0.4s]
